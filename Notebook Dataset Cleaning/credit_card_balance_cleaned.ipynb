# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('credit_card_balance.csv')
pd.set_option('display.max_columns', None)

# %%
df.sample(15)
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 799897      1649328      380671             -61    64130.040
# 604300      2108051      260802             -21        0.000
# 1472394     2007616      418390             -81      241.605
# 305803      2594144      242169             -82    99882.585
# 205224      1945223      136151             -53   173388.060
# 1413339     2665330      232092             -81    96286.140
# 3782877     2462336      216915             -52        0.000
# 1585302     2314246      292900             -55        0.000
# 2483568     2691414      326300             -18        0.000
# 3284738     2150138      203118             -94    53587.170
# 475754      1329680      328755             -63        0.000
# 1820184     1054526      181277              -4   132476.040
# 2360865     2524385      141318             -24        0.000
# 3323067     1065359      342754             -34        0.000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3840312 entries, 0 to 3840311
# Data columns (total 23 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   SK_ID_PREV                  int64
#  1   SK_ID_CURR                  int64
#  2   MONTHS_BALANCE              int64
#  3   AMT_BALANCE                 float64
#  4   AMT_CREDIT_LIMIT_ACTUAL     int64
#  5   AMT_DRAWINGS_ATM_CURRENT    float64
#  6   AMT_DRAWINGS_CURRENT        float64
#  7   AMT_DRAWINGS_OTHER_CURRENT  float64
#  8   AMT_DRAWINGS_POS_CURRENT    float64
#  9   AMT_INST_MIN_REGULARITY     float64
#  10  AMT_PAYMENT_CURRENT         float64
#  11  AMT_PAYMENT_TOTAL_CURRENT   float64
#  12  AMT_RECEIVABLE_PRINCIPAL    float64
#  13  AMT_RECIVABLE               float64
#  14  AMT_TOTAL_RECEIVABLE        float64
#  15  CNT_DRAWINGS_ATM_CURRENT    float64
#  16  CNT_DRAWINGS_CURRENT        int64
#  17  CNT_DRAWINGS_OTHER_CURRENT  float64
# ...

# %%
pd.set_option('display.max_columns', None)

# Pilih kolom-kolom bertipe objek dan simpan dalam variabel 'categoric'
categoric = df.select_dtypes('object')

# Pilih kolom-kolom bertipe numerik dan simpan dalam variabel 'numeric'
numeric = df.select_dtypes('number')

# Tentukan jumlah baris dan kolom
rows = df.shape[0]
cols = df.shape[1]

# Cetak bentuk DataFrame
print(f'Jumlah Baris: {rows}\nJumlah Kolom: {cols}')

# Cetak sampel 6 baris dari DataFrame
print('\nContoh Data:')
display(df.sample(6))

# Cetak ringkasan statistik data kategorikal
print('\nRingkasan Statistik Data Kategorikal:')
display(categoric.describe().T)

# Cetak ringkasan statistik data numerik
print('\nRingkasan Statistik Data Numerik:')
display(numeric.describe().T)

# Define categorical_col and numerical_col before printing
categorical_col = categoric.columns.tolist()  # Get the list of categorical columns
numerical_col = numeric.columns.tolist()    # Get the list of numerical columns
# Out:
# Jumlah Baris: 3840312
# Jumlah Kolom: 23
#
# Contoh Data:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 2134038     1096449      176846             -34         0.00
# 2055370     2658047      400780              -9         0.00
# 1100419     1421408      219714              -2         0.00
# 710616      2652298      228758             -23         0.00
# 13007       2155334      319733             -90      1428.48
# 2739197     1651989      448277              -1         0.00
#
#          AMT_CREDIT_LIMIT_ACTUAL  AMT_DRAWINGS_ATM_CURRENT  \
# 2134038                   225000                       NaN
# 2055370                        0                       0.0
# 1100419                   180000                       NaN
# 710616                     90000                       0.0
# 13007                      90000                       0.0
# 2739197                        0                       0.0
#
# ...

# %%
print("Categorical columns: ", categorical_col)
print("Numerical columns: ", numerical_col)
# Out:
# Categorical columns:  ['NAME_CONTRACT_STATUS']
# Numerical columns:  ['SK_ID_PREV', 'SK_ID_CURR', 'MONTHS_BALANCE', 'AMT_BALANCE', 'AMT_CREDIT_LIMIT_ACTUAL', 'AMT_DRAWINGS_ATM_CURRENT', 'AMT_DRAWINGS_CURRENT', 'AMT_DRAWINGS_OTHER_CURRENT', 'AMT_DRAWINGS_POS_CURRENT', 'AMT_INST_MIN_REGULARITY', 'AMT_PAYMENT_CURRENT', 'AMT_PAYMENT_TOTAL_CURRENT', 'AMT_RECEIVABLE_PRINCIPAL', 'AMT_RECIVABLE', 'AMT_TOTAL_RECEIVABLE', 'CNT_DRAWINGS_ATM_CURRENT', 'CNT_DRAWINGS_CURRENT', 'CNT_DRAWINGS_OTHER_CURRENT', 'CNT_DRAWINGS_POS_CURRENT', 'CNT_INSTALMENT_MATURE_CUM', 'SK_DPD', 'SK_DPD_DEF']

# %%
dfe = df.copy()
# Memeriksa baris duplikat
duplicate_rows = dfe.duplicated()

# Menampilkan jumlah baris duplikat
print(f"Jumlah baris duplikat: {duplicate_rows.sum()}")

# Fungsi untuk menghitung dan menampilkan kolom dengan nilai missing
def check_nan(dfe):
    # Hitung nilai null
    null_values = dfe.isnull().sum()

    # Buat DataFrame untuk total nilai null dan persentase
    nvc = pd.DataFrame(null_values[null_values > 0].sort_values(), columns=['Total Null Values'])  # Hanya ambil kolom dengan nilai null
    nvc['Percentage'] = (nvc['Total Null Values'] / dfe.shape[0]) * 100
    nvc["Data Type"] = [dfe[col].dtype for col in nvc.index]  # Ambil tipe data dari kolom yang ada

    # Urutkan berdasarkan total nilai null dan persentase
    nvc.sort_values(by=["Total Null Values", "Percentage"], ascending=False, inplace=True)

    # Tampilkan hasil dengan gaya
    return nvc.style.background_gradient(cmap='Blues')

# Panggil fungsi dan simpan hasilnya
styled_result = check_nan(dfe)

# Untuk menampilkan hasil di Jupyter Notebook, gunakan:
styled_result
# Out:
# Jumlah baris duplikat: 0
# <style type="text/css">
# #T_8878e_row0_col0, #T_8878e_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8878e_row1_col0, #T_8878e_row1_col1, #T_8878e_row2_col0, #T_8878e_row2_col1, #T_8878e_row3_col0, #T_8878e_row3_col1, #T_8878e_row4_col0, #T_8878e_row4_col1, #T_8878e_row5_col0, #T_8878e_row5_col1, #T_8878e_row6_col0, #T_8878e_row6_col1 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_8878e_row7_col0, #T_8878e_row7_col1, #T_8878e_row8_col0, #T_8878e_row8_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_8878e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8878e_level0_col0" class="col_heading level0 col0" >Total Null Values</th>
#       <th id="T_8878e_level0_col1" class="col_heading level0 col1" >Percentage</th>
#       <th id="T_8878e_level0_col2" class="col_heading level0 col2" >Data Type</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
# 1. Hitung total dan persentase missing value
missing = dfe.isnull().sum() / len(dfe) * 100
missing = missing[missing > 0].sort_values(ascending=False)
print("Missing Value Percentage:\n", missing)
# Out:
# Missing Value Percentage:
#  AMT_PAYMENT_CURRENT           19.998063
# AMT_DRAWINGS_ATM_CURRENT      19.524872
# AMT_DRAWINGS_OTHER_CURRENT    19.524872
# AMT_DRAWINGS_POS_CURRENT      19.524872
# CNT_DRAWINGS_ATM_CURRENT      19.524872
# CNT_DRAWINGS_OTHER_CURRENT    19.524872
# CNT_DRAWINGS_POS_CURRENT      19.524872
# AMT_INST_MIN_REGULARITY        7.948208
# CNT_INSTALMENT_MATURE_CUM      7.948208
# dtype: float64

# %% [markdown]
# Semua kolom yang hilang ini:
#
# Bersifat numerik float/int)
#
# Memiliki distribusi skewed atau mengandung outlier
#
# Tidak bersifat kategorikal, sehingga imputasi median adalah pendekatan yang tepat

# %%
from sklearn.impute import SimpleImputer

# Kolom yang missing value-nya antara 5% dan 50%
to_impute = missing[(missing > 5) & (missing <= 50)].index.tolist()

# Gunakan median untuk menghindari outlier effect
imputer = SimpleImputer(strategy='median')
dfe[to_impute] = imputer.fit_transform(dfe[to_impute])

# Kolom dengan missing value < 5%
low_missing = missing[missing <= 5].index.tolist()
# Drop baris yang memiliki null pada kolom tersebut
if len(low_missing) > 0:
    dfe = dfe.dropna(subset=low_missing)

# %%
# Panggil fungsi dan simpan hasilnya
styled_result = check_nan(dfe)

# Untuk menampilkan hasil di Jupyter Notebook, gunakan:
styled_result
# Out:
# <style type="text/css">
# </style>
# <table id="T_6872a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6872a_level0_col0" class="col_heading level0 col0" >Total Null Values</th>
#       <th id="T_6872a_level0_col1" class="col_heading level0 col1" >Percentage</th>
#       <th id="T_6872a_level0_col2" class="col_heading level0 col2" >Data Type</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
dfe.to_csv('credit_card_balance_cleaned.csv', index=False)
